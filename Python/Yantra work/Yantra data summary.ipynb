# %%
import pandas as pd

# %%
all_data = pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vTHecW3PsMZNuX19IxzoC2UkLlY3Ezh-WK9Dly6tkiQinZwH2Q7R2RxjEdk9_jyUOZQndGWTmnOc1uW/pubhtml", header=0)

# %%
all_data[0]
# Out:
#       Unnamed: 0            Unnamed: 1       Unnamed: 2        Unnamed: 3  \
# 0              1                  Name  Date of Calling        Phone Call
# 1              2          Parul Chopra           29-Dec               Yes
# 2              3      Ruwan Taleyratne           22-Jan               Yes
# 3              4          Gaurav bajaj           27-Mar               Yes
# 4              5  Vijayendran Chandran           19-Feb               Yes
# ...          ...                   ...              ...               ...
# 5043        5044                Avijit            5-Feb   WA Message Sent
# 5044        5045                Martha            5-Feb   WA Message Sent
# 5045        5046                  dani              NaN  Number not on WA
# 5046        5047                   Jet              NaN  Number not on WA
# 5047        5048                  Kemo            5-Feb   WA Message Sent
#
#          Unnamed: 4 Unnamed: 5  \
# 0          Response      Email
# ...

# %%
all_data[0].describe(include='all')
# Out:
#         Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# count   5048.00000       5048        4040       4654         4607        1989
# unique         NaN       3828         416         12            9           4
# top            NaN      Rahul  26-12-2021        Yes  No Response  First Mail
# freq           NaN         21         103       1893         2461        1565
# mean    2524.50000        NaN         NaN        NaN          NaN         NaN
# std     1457.37641        NaN         NaN        NaN          NaN         NaN
# min        1.00000        NaN         NaN        NaN          NaN         NaN
# 25%     1262.75000        NaN         NaN        NaN          NaN         NaN
# 50%     2524.50000        NaN         NaN        NaN          NaN         NaN
# 75%     3786.25000        NaN         NaN        NaN          NaN         NaN
# max     5048.00000        NaN         NaN        NaN          NaN         NaN
#
# ...

# %%
all_data[0].head()
# Out:
#    Unnamed: 0            Unnamed: 1       Unnamed: 2  Unnamed: 3  \
# 0           1                  Name  Date of Calling  Phone Call
# 1           2          Parul Chopra           29-Dec         Yes
# 2           3      Ruwan Taleyratne           22-Jan         Yes
# 3           4          Gaurav bajaj           27-Mar         Yes
# 4           5  Vijayendran Chandran           19-Feb         Yes
#
#       Unnamed: 4 Unnamed: 5  \
# 0       Response      Email
# 1  Next Ceremony  Reg Email
# 2     Registered  Reg Email
# 3     Registered  Reg Email
# 4     Registered  Reg Email
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                            Remarks  Follow up
# 1  Both done IE, no children, wants to gift Gudi ...        NaN
# 2  Is married, Wife Manories., originaly from Sri...         NO
# 3  Works for IT, married, wants Avighna / 20 Oct ...        NaN
# 4  Lives in US - Florida, native of ooty, parents...        NaN
#
# ...

# %%
pd.read_html?
