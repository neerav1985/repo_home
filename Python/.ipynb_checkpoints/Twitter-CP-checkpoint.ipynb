# %%
import tweepy
import random
from tqdm import tqdm
from time import sleep
from credentials import CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET, API_KEY, API_KEY_SECRET
from config import QUERY, FOLLOW, LIKE, SLEEP_TIME
  
    
# auth = tweepy.OAuthHandler(CLIENT_ID, CLIENT_SECRET)    
auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)
print(api)
# print(len(list(tweepy.Cursor(api.search_tweets, q = QUERY).items())))
# Out:
# <tweepy.api.API object at 0x000001744245D040>

# %%
def divide_chunks(l, n):
    for i in range(0, len(l), n): 
        yield l[i:i + n]
        
def get_followers(screen_name):
    ids = []
    for page in tweepy.Cursor(api.get_follower_ids, screen_name=screen_name).pages():
        ids.extend(page)
        sleep(60)
    return [user.screen_name  for id_chunk in divide_chunks(ids,100) for user in api.lookup_users(user_id=id_chunk) ]
    
def retweet_tweet(tweet, retweet_count=20):
    if not tweet.retweeted and tweet.retweet_count>retweet_count: 
        tweet.retweet()
        return True
    return False
                  
def favorite_tweet(tweet, favorite_count=20):
    if not tweet.favorited and tweet.favorite_count>favorite_count: 
        tweet.favorite()
        return True
    return False

def follow_user(user):
    if not user.following:
        user.follow()
        return True
    return False

def get_user(screen_name='',user_id=''):
    if screen_name: 
        return api.get_user(screen_name=screen_name)
    elif user_id:
        return api.get_user(screen_name=screen_name)
    else:
        raise Exception('Provide kwarg screen_name or user_id')

def get_tweet(tweet_id):
    return api.get_status(tweet_id)
        
#     * mixed : include both popular and real time results in the response
#     * recent : return only the most recent results in the response
#     * popular : return only the most popular results in the response

# %%
cp_followers = get_followers("@cpsavesoil")
len(cp_followers)

# %%
  
total_retweets = 0
total_favorites = 0
total_follows = 0
total_allowed = 50
pbar = tqdm(total=total_allowed)
# result_type='mixed',  result_type='popular', result_type='latest'
for tweet in tweepy.Cursor(api.search_tweets, q = QUERY,since="2021-01-01").items(): 
    try:
        total_retweets += retweet_tweet(tweet)
        total_favorites += favorite_tweet(tweet)
        total_follows += follow_user(tweet.user)
        sleep(SLEEP_TIME)
#         print(total_retweets + total_favorites + total_follows)
        pbar.update(total_retweets + total_favorites + total_follows)
        if total_retweets + total_favorites + total_follows >=total_allowed:
            pbar.close()
            break
    except tweepy.TweepyException as e:
        pass  
    except StopIteration:
        break
print("total_retweets:",total_retweets)
print("total_favorites:",total_favorites)
print("total_follows:",total_follows)


#TODO: collect images and videos and start tweeting independent posts and reply to existing posts - create 25 posts with media
#TODO: consider using the existing tweeted media and try to tweet using that
#TODO: start mentioning people to these tweets
#TODO: how to use different apps? 10 apps can be used per user
#TODO: consider using @consciousplanet existing tweets and media
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]Unexpected parameter: since
#
#
#
#   1%|▊                                                                                 | 1/100 [00:02<04:00,  2.43s/it]
#
#
#   4%|███▎                                                                              | 4/100 [00:04<03:03,  1.92s/it]
#
#
#   8%|██████▌                                                                           | 8/100 [00:06<02:14,  1.46s/it]
#
#
#  13%|██████████▌                                                                      | 13/100 [00:07<01:37,  1.12s/it]
#
#
#  19%|███████████████▍                                                                 | 19/100 [00:09<01:10,  1.15it/s]
#
#
#  26%|█████████████████████                                                            | 26/100 [00:11<00:49,  1.49it/s]
#
#
#  35%|████████████████████████████▎                                                    | 35/100 [00:13<00:36,  1.78it/s]
#
#
#  46%|█████████████████████████████████████▎                                           | 46/100 [00:16<00:25,  2.15it/s]
#
#
#  58%|██████████████████████████████████████████████▉                                  | 58/100 [00:17<00:15,  2.74it/s]
#
#
#  72%|██████████████████████████████████████████████████████████▎                      | 72/100 [00:22<00:09,  2.88it/s]
#
#
#  87%|██████████████████████████████████████████████████████████████████████▍          | 87/100 [00:23<00:03,  3.63it/s]Unexpected parameter: since
#
#
#
# 104it [00:27,  3.97it/s]
#
#
# 122it [00:28,  4.93it/s]
#
#
# 140it [00:29,  6.30it/s]
#
#
# 159it [00:31,  6.92it/s]
#
#
# 180it [00:36,  6.14it/s]
#
#
# 203it [00:40,  6.10it/s]Unexpected parameter: since
#
#
#
# 227it [00:42,  7.02it/s]
#
#
# 252it [00:43,  8.44it/s]
#
#
# 278it [00:45,  9.92it/s]
#
#
# 304it [00:46, 12.15it/s]
#
#
# 332it [00:48, 12.40it/s]
#
#
# 361it [00:50, 13.73it/s]
#
#
# 391it [00:53, 12.08it/s]
#
#
# 422it [00:54, 13.56it/s]
#
#
# 455it [00:57, 12.92it/s]
#
#
# 488it [00:58, 15.78it/s]Unexpected parameter: since
#
#
#
# 521it [01:01, 15.49it/s]
#
#
# 555it [01:04, 13.60it/s]
#
#
# 589it [01:05, 15.37it/s]
#
#
# 624it [01:07, 16.91it/s]
#
#
# 661it [01:11, 13.17it/s]
#
#
# 699it [01:13, 15.15it/s]
#
#
# 737it [01:14, 18.45it/s]Unexpected parameter: since
#
#
#
# 775it [01:17, 15.77it/s]
#
#
# 814it [01:19, 16.50it/s]
#
#
# 854it [01:21, 18.50it/s]
#
#
# 895it [01:23, 18.61it/s]
#
#
# 936it [01:24, 20.58it/s]
#
#
# 977it [01:25, 24.13it/s]
#
#
# 1018it [01:28, 21.37it/s]Unexpected parameter: since
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-15-1ff4cb11e8f3> in <module>
#       4 total_allowed = 100
#       5 pbar = tqdm(total=total_allowed)
# ----> 6 for tweet in tweepy.Cursor(api.search_tweets, q = QUERY,since="20121-01-01").items(): # result_type='mixed',  result_type='latest'
#       7     try:
#       8         total_retweets += retweet_tweet(tweet)
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# C:\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# C:\Anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# C:\Anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# C:\Anaconda3\lib\site-packages\tweepy\api.py in search_tweets(self, q, **kwargs)
#    1266         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/api-reference/get-search-tweets
#    1267         """
# -> 1268         return self.request(
#    1269             'GET', 'search/tweets', endpoint_parameters=(
#    1270                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# C:\Anaconda3\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     257                 raise Unauthorized(resp)
#     258             if resp.status_code == 403:
# --> 259                 raise Forbidden(resp)
#     260             if resp.status_code == 404:
#     261                 raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 326 - To protect our users from spam and other malicious activity, this account is temporarily locked. Please log in to https://twitter.com to unlock your account.
# 1018it [01:45, 21.37it/s]

# %%
total_allowed = 50
mention_tweets_per_tweet= 1
pbar = tqdm(total=total_allowed)
total=0
pbar = tqdm(total=len(tweet_ids)*mention_tweets_per_tweet)
for tweet in tweepy.Cursor(api.search_tweets, q = QUERY).items():
    for i in range(mention_tweets_per_tweet):
        aa = "The time to act is running out! \nJoin hands with #SaveSoil warriors\n@" + " @".join(random.sample(cp_followers,10)) + "\n#ConsciousPlanet "
#         print(aa)
        api.update_status(status = aa, in_reply_to_status_id = tweet.id , auto_populate_reply_metadata=True)
        total+=1
        pbar.update(total)
        sleep(random.randint(30,60))
pbar.close()
# Out:
#   File "<ipython-input-3-025f63513e2f>", line 2
#     tweepy.Cursor(api.search_tweets, q = QUERY).items()[0].id:
#                                                               ^
# SyntaxError: invalid syntax

# %%
tweet = get_tweet(1490558750645944321)

# %%
tweet.id
# Out:
# 1490558750645944321

# %%
len(cp_followers)
# Out:
# 6513

# %%
import random
# Out:
# Like/Retweet to spread the word
# Follow #SaveSoil warriors
# @Maharudrayya7
# @u4utkam
# @SimmiGu47409116
# @Ramacha49227557
# @Bhuvaneswari83
# @Basavar89081586
# @mr_suthi3
# @iamakk1
# @TKrautmann
# @JBRHarsh

# %%
tweet_ids=[1490611895178448900]
mention_tweets_per_tweet= random.randint(3,6)
total=0
pbar = tqdm(total=len(tweet_ids)*mention_tweets_per_tweet)
for tweet_id in tweet_ids:
    for i in range(mention_tweets_per_tweet):
        aa = "Problem: Soil extinction.\n\n\n Solution: Tree-based agriculture. \nJoin hands with #SaveSoil warriors\n@" + " @".join(random.sample(cp_followers,10)) + "\n#ConsciousPlanet "
#         print(aa)
        api.update_status(status = aa, in_reply_to_status_id = tweet_id , auto_populate_reply_metadata=True)
        total+=1
        pbar.update(total)
        sleep(random.randint(30,60))
pbar.close()
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
#
#  20%|████████████████▊                                                                   | 1/5 [00:00<00:03,  1.31it/s]
#
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [00:37<00:12,  6.02s/it]
#
# 6it [01:27,  9.28s/it]
#
# 10it [02:10,  9.69s/it]
#
# 15it [03:27, 13.81s/it]

# %%
"@" + " @".join(random.sample(cp_followers,10))
# Out:
# '@MaxIsha90 @DeviDevi0110 @karishmam25 @Bharath_tiru @Likhitha_here @marvlsp11 @Mote17Prashant @InnaMerkushova @Stoby03 @I_amsavi'

# %%
quote_tweet_urls = ["https://twitter.com/SadhguruJV/status/1490013796726837248"]
mention_tweets_per_tweet= random.randint(3,6)
total=0
pbar = tqdm(total=len(quote_tweet_urls)*mention_tweets_per_tweet)
for quote_url in quote_tweet_urls:
    for i in range(mention_tweets_per_tweet):
        aa = "Soil extinction means human extinction. \nJoin hands with #SaveSoil warriors\n@" + " @".join(random.sample(cp_followers,10)) + "\n#ConsciousPlanet "
#         print(aa)
        api.update_status(status = aa, attachment_url = quote_url )
        total+=1
        pbar.update(total)
        sleep(random.randint(30,60))
pbar.close()
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
#
#  20%|████████████████▊                                                                   | 1/5 [00:00<00:02,  1.57it/s]
#
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [00:52<00:16,  8.20s/it]
#
# 6it [01:41, 10.61s/it]
#
# 10it [02:38, 11.76s/it]
#
# 15it [04:07, 16.50s/it]

# %%
tweet_ids = [1490595688295456784,]
# Out:
# 'Save Soil: Our Very Body | Conscious Planet https://t.co/DapOROHBgl via @YouTube'

# %%
total_mentions = 0
total_allowed = 40
pbar = tqdm(total=total_allowed)
for tweet in tweepy.Cursor(api.search_tweets, q = "#SaveSoil", result_type='popular').items():
    try:
        total_mentions += mention_tweet(tweet)
        sleep(SLEEP_TIME)
        pbar.update(total_mentions)
        if total_mentions >=total_allowed:
            pbar.close()
            break
    except tweepy.TweepyException as e:
        pass
  
    except StopIteration:
        break
print("total_mentions:",total_mentions)

# %%
api.search_tweets?

# %%
dir(tweet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'extended_entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
dir(tweepy)
# Out:
# ['API',
#  'AppAuthHandler',
#  'BadRequest',
#  'Cache',
#  'Client',
#  'Cursor',
#  'FileCache',
#  'Forbidden',
#  'HTTPException',
#  'List',
#  'Media',
#  'MemoryCache',
#  'NotFound',
#  'OAuth1UserHandler',
#  'OAuth2AppHandler',
#  'OAuth2BearerHandler',
#  'OAuth2UserHandler',
#  'OAuthHandler',
#  'Paginator',
#  'Place',
#  'Poll',
#  'ReferencedTweet',
#  'Response',
#  'Space',
#  'Stream',
#  'TooManyRequests',
#  'TweepyException',
#  'Tweet',
#  'TwitterServerError',
#  'Unauthorized',
#  'User',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'api',
#  'auth',
#  'cache',
#  'client',
#  'cursor',
#  'debug',
#  'errors',
#  'list',
#  'media',
#  'mixins',
#  'models',
#  'pagination',
#  'parsers',
#  'place',
#  'poll',
#  'space',
#  'streaming',
#  'tweet',
#  'user',
#  'utils']

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']

# %%
user = api.get_user(screen_name='@neerav1985')

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '96060604-d6WNH9LQdYSfVjALkbZjZR6NB3K8XoeUT0oY5KktN'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/lists/:id/tweets&GET': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/lists/:id/followers&GET': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1644136530},
#    '/lists/:id&DELETE': {'limit': 300, 'remaining': 300, 'reset': 1644136530},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/lists/:id&GET': {'limit': 75, 'remaining': 75, 'reset': 1644136530},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/lists/:id&PUT': {'limit': 300, 'remaining': 300, 'reset': 1644136530},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1644136530},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/lists/:id/members/:user_id&DELETE': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1644136530},
#    '/lists/:id/members&POST': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/lists/:id/members&GET': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1644136530}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530}},
#   'mutes': {'/mutes/users/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'verify': {'/verify/:version/badge-violation': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/verify/:version/badge-violation/violations': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/verify/:version/intake': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/verify/:version/document-formats': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/verify/:version/id-document&GET': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530},
#    '/verify/:version/id-document&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/verify/:version/access': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/verify/:version/account-eligibility': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'admin_users': {'/admin_users': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1644136530}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530}},
#   'friendships': {'/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1644136530},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1644136530}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1644136530},
#    '/guide/get_explore_locations': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/guide/explore_locations_with_autocomplete': {'limit': 200,
#     'remaining': 200,
#     'reset': 1644136530}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'compliance': {'/compliance/jobs&POST': {'limit': 150,
#     'remaining': 150,
#     'reset': 1644136530},
#    '/compliance/jobs&GET': {'limit': 150,
#     'remaining': 150,
#     'reset': 1644136530},
#    '/compliance/jobs/:job_id': {'limit': 150,
#     'remaining': 150,
#     'reset': 1644136530}},
#   'paseto': {'/paseto/token': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1644136530},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1644136530},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'users': {'/users/': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:id/list_memberships&GET': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/users/:id': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:id/muting&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/:id/pinned_lists/:list_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/:source_user_id/blocking/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1644136530},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:source_user_id/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/:id/tweets': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:id/retweets/:source_tweet_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:id/likes&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1644136530},
#    '/users/:id/retweets&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/users/by/username/:source_username/following/:target_user_name&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/by/username/:handle/tweets': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/:id/blocking&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/by/username/:source_username/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/:id/followers': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/:id/muting': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/:id/pinned_lists&GET': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/:id/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/users/:id/following': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/:id/pinned_lists&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/:source_user_id/following/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/by/username/:username': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/users/:id/owned_lists&GET': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/:id/followed_lists&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/by/username/:username/followers': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:id/followed_lists/:list_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/:id/blocking': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/users/:id/likes/:tweet_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/by/username/:username/following': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/by/username/:handle/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/users/by': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/users/:source_user_id/muting/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/users/:id/followed_lists&GET': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/users/:id/liked_tweets': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530}},
#   'teams': {'/teams/authorize': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530}},
#   'permissions': {'/permissions/user_permissions/admin_email_verification': {'limit': 3,
#     'remaining': 3,
#     'reset': 1644136530},
#    '/permissions/user_permissions': {'limit': 3,
#     'remaining': 3,
#     'reset': 1644136530}},
#   'tweets&POST': {'/tweets&POST': {'limit': 200,
#     'remaining': 200,
#     'reset': 1644136530}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1644136530},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1644136530}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1644136530},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530}},
#   'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#     'remaining': 5,
#     'reset': 1644136530},
#    '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#     'remaining': 10,
#     'reset': 1644136530},
#    '/labs/:version/tweets/stream/filter/': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/labs/:version/users/:id/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1644136530},
#    '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1644136530},
#    '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/labs/:version/tweets/stream/sample': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/labs/:version/users/by/username/:handle/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1644136530},
#    '/labs/:version/tweets/metrics/private': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/labs/:version/tweets/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/labs/:version/users/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/labs/:version/tweets/stream/compliance': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530},
#    '/labs/:version/tweets/search': {'limit': 225,
#     'remaining': 225,
#     'reset': 1644136530}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1644136530},
#    '/moments/create': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530}},
#   'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#     'remaining': 4500,
#     'reset': 1644136530}},
#   'fleets': {'/fleets/:version/mutes/create': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/viewers': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/delete': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/fleets/:version/avatar_content': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/create': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/fleets/:version/user_fleets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/fleets/:version/fleetline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/track_events': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/update': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/fleets/:version/fleet_threads': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530},
#    '/fleets/:version/mutes/list': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/mutes/destroy': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/home_timeline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1644136530},
#    '/fleets/:version/feedback/create': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530},
#    '/fleets/:version/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530}},
#   'graphql&POST': {'/graphql&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1644136530},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1644136530},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1644136530},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1644136530},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1644136530},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1644136530},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'strato': {'/strato/column/None/:id/cms/*': {'limit': 150,
#     'remaining': 150,
#     'reset': 1644136530}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1644136530},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/account/authenticate_web_view': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1644136530},
#    '/account/change_password': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1644136530}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530}},
#   'lists&POST': {'/lists&POST': {'limit': 300,
#     'remaining': 300,
#     'reset': 1644136530}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'tweets': {'/tweets/search/all': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/tweets/search/stream/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/tweets/search/recent': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530},
#    '/tweets/sample/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/tweets/:id&DELETE': {'limit': 50, 'remaining': 50, 'reset': 1644136530},
#    '/tweets/': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/tweets/counts/all': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/tweets/search/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1644136530},
#    '/tweets/search/stream/rules/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/tweets/:id/retweeted_by': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/tweets/:tweet_id/liking_users': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/tweets/:id': {'limit': 900, 'remaining': 900, 'reset': 1644136530},
#    '/tweets/search/stream/rules&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/tweets/counts/recent': {'limit': 900,
#     'remaining': 900,
#     'reset': 1644136530},
#    '/tweets/search/stream/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/tweets/:id/hidden&PUT': {'limit': 50,
#     'remaining': 50,
#     'reset': 1644136530}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}},
#   'oauth': {'/oauth/revoke': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530},
#    '/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1644136530},
#    '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1644136530}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1644136530},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1644136530},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1644136530}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1644136530}},
#   'graphql': {'/graphql': {'limit': 15,
#     'remaining': 15,
#     'reset': 1644136530}}}}

# %%
followers = api.get_followers(screen_name='neerav1985', count=400)

# %%
for tweet in tweepy.Cursor(api.get_followers, screen_name = 'QUERY').items()
# Out:
# 20

# %%
# Out:
# 449

# %%
len(screen_names), screen_names[:5]
# Out:
# (449,
#  ['saravjeet_arora',
#   'JuliaPokorna',
#   'Priya247Patel',
#   'sacredbalance',
#   'shamjadhav185'])

# %%
help(api.update_status)
# Out:
# Help on method update_status in module tweepy.api:
#
# update_status(status, **kwargs) method of tweepy.api.API instance
#     update_status(             status, *, in_reply_to_status_id, auto_populate_reply_metadata,             exclude_reply_user_ids, attachment_url, media_ids,             possibly_sensitive, lat, long, place_id, display_coordinates,             trim_user, card_uri         )
#
#     Updates the authenticating user's current status, also known as
#     Tweeting.
#
#     For each update attempt, the update text is compared with the
#     authenticating user's recent Tweets. Any attempt that would result in
#     duplication will be blocked, resulting in a 403 error. A user cannot
#     submit the same status twice in a row.
#
#     While not rate limited by the API, a user is limited in the number of
#     Tweets they can create at a time. If the number of updates posted by
#     the user reaches the current allowed limit this method will return an
#     HTTP 403 error.
#
#     Parameters
#     ----------
#     status
#         The text of your status update.
#     in_reply_to_status_id
#         The ID of an existing status that the update is in reply to. Note:
#         This parameter will be ignored unless the author of the Tweet this
#         parameter references is mentioned within the status text.
#         Therefore, you must include @username, where username is the author
#         of the referenced Tweet, within the update.
#     auto_populate_reply_metadata
#         If set to true and used with in_reply_to_status_id, leading
#         @mentions will be looked up from the original Tweet, and added to
#         the new Tweet from there. This wil append @mentions into the
#         metadata of an extended Tweet as a reply chain grows, until the
#         limit on @mentions is reached. In cases where the original Tweet
#         has been deleted, the reply will fail.
#     exclude_reply_user_ids
#         When used with auto_populate_reply_metadata, a comma-separated list
#         of user ids which will be removed from the server-generated
#         @mentions prefix on an extended Tweet. Note that the leading
#         @mention cannot be removed as it would break the
#         in-reply-to-status-id semantics. Attempting to remove it will be
#         silently ignored.
#     attachment_url
#         In order for a URL to not be counted in the status body of an
#         extended Tweet, provide a URL as a Tweet attachment. This URL must
#         be a Tweet permalink, or Direct Message deep link. Arbitrary,
#         non-Twitter URLs must remain in the status text. URLs passed to the
#         attachment_url parameter not matching either a Tweet permalink or
#         Direct Message deep link will fail at Tweet creation and cause an
#         exception.
#     media_ids
#         A list of media_ids to associate with the Tweet. You may include up
#         to 4 photos or 1 animated GIF or 1 video in a Tweet.
#     possibly_sensitive
#         If you upload Tweet media that might be considered sensitive
#         content such as nudity, or medical procedures, you must set this
#         value to true.
#     lat
#         The latitude of the location this Tweet refers to. This parameter
#         will be ignored unless it is inside the range -90.0 to +90.0 (North
#         is positive) inclusive. It will also be ignored if there is no
#         corresponding long parameter.
#     long
#         The longitude of the location this Tweet refers to. The valid
#         ranges for longitude are -180.0 to +180.0 (East is positive)
#         inclusive. This parameter will be ignored if outside that range, if
#         it is not a number, if geo_enabled is disabled, or if there no
#         corresponding lat parameter.
#     place_id
#         A place in the world.
#     display_coordinates
#         Whether or not to put a pin on the exact coordinates a Tweet has
#         been sent from.
#     trim_user
#         |trim_user|
#     card_uri
#         Associate an ads card with the Tweet using the card_uri value from
#         any ads card response.
#
#     Returns
#     -------
#     :class:`~tweepy.models.Status`
#
#     References
#     ----------
#     https://developer.twitter.com/en/docs/twitter-api/v1/tweets/post-and-engage/api-reference/post-statuses-update

# %%
tweepy.API?

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']
